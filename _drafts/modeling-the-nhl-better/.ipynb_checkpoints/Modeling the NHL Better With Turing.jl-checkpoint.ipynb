# %%
using CSV
using Random
using Turing
using DataFrames
using Distributions
using Plots
using StatsPlots
using MCMCChains
using StatsFuns
using ReverseDiff
using Memoization
using SpecialFunctions

seed = 1234
# Out:
# 1234

# %%
path = "/home/everett/Development/everettsprojects.com/_drafts/modeling-the-nhl-better/"
games_full = CSV.File(path*"ideal_games.csv") |> DataFrame!
latent_variables = CSV.File(path*"latent_variables.csv") |> DataFrame!
n_teams = maximum([maximum(games_full[:,:home_id]), maximum(games_full[:,:away_id])])
;

# %%
n_teams
# Out:
# 6

# %% [markdown]
# ### Model

# %%
Turing.setadbackend(:reversediff)
Turing.setrdcache(true)
# Out:
# true

# %%
# https://github.com/StatisticalRethinkingJulia/MCMCBenchmarks.jl/pull/39
struct LogPoisson{T<:Real} <: Distributions.DiscreteUnivariateDistribution
    logλ::T
end

function Distributions.logpdf(lp::LogPoisson, k::Int)
    return k * lp.logλ - exp(lp.logλ) - (logabsgamma(k + 1))[1]
end

# https://github.com/JuliaStats/Distributions.jl/issues/1070
function Distributions.fit_mle(::Type{<:InverseGamma}, x::AbstractArray{Float64})
    fg = fit(Gamma, x.^(-1))
    return InverseGamma(fg.α, 1/fg.θ)
end

# %%
# Define an equivalent to my PyMC3 model
@model function nhl_inference(idₕ, idₐ, sₕ, sₐ, hw, p)
    Δσₕ ~ InverseGamma(p[:Δσₕ][1], p[:Δσₕ][2])
    Δσᵢ ~ InverseGamma(p[:Δσᵢ][1], p[:Δσᵢ][2])
    Δσₜₑₐₘ ~ InverseGamma(p[:Δσₜₑₐₘ][1], p[:Δσₜₑₐₘ][2])
    Δₕ ~ Normal(0.0, Δσₕ)
    Δᵢ ~ Normal(0.0, Δσᵢ)
    h ~ Normal(p[:h][1], p[:h][2])
    h = h + Δₕ
    i ~ Normal(p[:i][1], p[:i][2])
    i = i + Δᵢ
    o ~ arraydist(Normal.(p[:o][1], p[:o][2]))
    d ~ arraydist(Normal.(p[:d][1], p[:d][2]))
    Δo ~ filldist(Normal(0.0, Δσₜₑₐₘ), n_teams)
    Δd ~ filldist(Normal(0.0, Δσₜₑₐₘ), n_teams)
    o = o .+ Δo
    d = d .+ Δd
    o₀ = o .- mean(mean.(o))
    d₀ = d .- mean(mean.(d))
    log_λₕ = i .+ h .+ o₀[idₕ] .- d₀[idₐ]
    log_λₐ = i .+ o₀[idₐ] .- d₀[idₕ]
    sₕ .~ LogPoisson.(log_λₕ)
    sₐ .~ LogPoisson.(log_λₐ)
    ℓ = logistic.(log_λₕ .- log_λₐ)
    hw .~ BernoulliLogit.(ℓ)
end
;

# %%
# Define an equivalent to my PyMC3 model
#@model function nhl_inference(idₕ, idₐ, sₕ, sₐ, hw, p)
#    h ~ Normal(p[:h][1], p[:h][2])
#    i ~ Normal(p[:i][1], p[:i][2])
#    o ~ arraydist(Normal.(p[:o][1], p[:o][2]))
#    d ~ arraydist(Normal.(p[:d][1], p[:d][2]))
#    o₀ = o .- mean(mean.(o))
#    d₀ = d .- mean(mean.(d))
#    log_λₕ = i .+ h .+ o₀[idₕ] .- d₀[idₐ]
#    log_λₐ = i .+ o₀[idₐ] .- d₀[idₕ]
#    sₕ .~ LogPoisson.(log_λₕ)
#    sₐ .~ LogPoisson.(log_λₐ)
#    ℓ = logistic.(log_λₕ .- log_λₐ)
#    hw .~ BernoulliLogit.(ℓ)
#end
#;

# %%
function get_posteriors(chain, n_teams)
    chdf = DataFrame(chain)
    p = Dict()
    Δσₕ_mle = fit_mle(InverseGamma, chdf[:, "Δσₕ"])
    p[:Δσₕ] = (Δσₕ_mle.invd.α, Δσₕ_mle.θ)
    Δσᵢ_mle = fit_mle(InverseGamma, chdf[:, "Δσᵢ"])
    p[:Δσᵢ] = (Δσᵢ_mle.invd.α, Δσᵢ_mle.θ)
    Δσₜₑₐₘ_mle = fit_mle(InverseGamma, chdf[:, "Δσₜₑₐₘ"])
    p[:Δσₜₑₐₘ] = (Δσₜₑₐₘ_mle.invd.α, Δσₜₑₐₘ_mle.θ)
    h_mle = fit_mle(Normal, chdf[:,"h"])
    p[:h] = (h_mle.μ, h_mle.σ)
    i_mle = fit_mle(Normal, chdf[:,"i"])
    p[:i] = (i_mle.μ, i_mle.σ)
    p[:o] = ([], [])
    p[:d] = ([], [])
    for t = 1:n_teams
        o_mle = fit_mle(Normal, chdf[:,"o[$(t)]"])
        push!(p[:o][1], o_mle.μ)
        push!(p[:o][2], o_mle.σ)
        d_mle = fit_mle(Normal, chdf[:,"d[$(t)]"])
        push!(p[:d][1], d_mle.μ)
        push!(p[:d][2], d_mle.σ)
    end
    return p
end

function get_posterior_μ(posteriors)
    p = [posteriors[:h][1], posteriors[:i][1]]
    p = vcat(p, posteriors[:o][1])
    p = vcat(p, posteriors[:d][1])
    return p
end
# Out:
# get_posterior_μ (generic function with 1 method)

# %%
o_init = [latent_variables[1, "o$(t)"] for t in 1:n_teams]
d_init = [latent_variables[1, "d$(t)"] for t in 1:n_teams]
# Out:
# 6-element Array{Float64,1}:
#   0.012806443451512646
#   0.1852782957725545
#  -0.08277634318169205
#   0.011009612632217553
#  -0.02511757400198831
#   0.03697140350317454

# %%
start_day = 500
ws = 1
s = 1
end_day = 600

n_days = end_day - start_day

inferred_variables = DataFrame(
    day = [],
    Δₕ = [],
    Δᵢ = [],
    Δₜₑₐₘ = [],
    h = [],
    i = []
)

for i = 1:n_teams
    inferred_variables["o$i"] = []
    inferred_variables["d$i"] = []
end

priors = Dict(
    :Δσₕ => (5.0, 0.05),
    :Δσᵢ => (5.0, 0.05),
    :Δσₜₑₐₘ => (5.0, 0.05),
    :h => (0.25, 0.05),
    :i => (1.12, 0.05),
    :o => (o_init, ones(n_teams)*0.05),
    :d => (d_init, ones(n_teams)*0.05)
)


for t = 1:s:(end_day - start_day + 1)
    day = t + start_day - 1

    if t == 1
        games = filter(row -> (row[:day] <= day), games_full)
        println(minimum(games[:,:day]))
        idₕ = Vector{Int64}(games[:,:home_id])
        idₐ = Vector{Int64}(games[:,:away_id])
        sₕ = Vector{Int64}(games[:,:home_score])
        sₐ = Vector{Int64}(games[:,:away_score])
        hw = Vector{Int64}(games[:,:home_win])
        m = nhl_inference(idₕ, idₐ, sₕ, sₐ, hw, priors)
        #est = optimize(m, MAP())
        #priors_μ = est.values.array
        #print(priors_μ)
        #chain = sample(m, HMCDA(200, 0.65, 0.3), 500, init_theta = priors_μ)
        chain = sample(m, NUTS(500, 0.65), 2000)#, init_theta = priors_μ)
    else
        games = filter(row -> ((row[:day] <= day) .& (row[:day] > (day - ws))), games_full)
        println(minimum(games[:,:day]))
        idₕ = Vector{Int64}(games[:,:home_id])
        idₐ = Vector{Int64}(games[:,:away_id])
        sₕ = Vector{Int64}(games[:,:home_score])
        sₐ = Vector{Int64}(games[:,:away_score])
        hw = Vector{Int64}(games[:,:home_win])
        m = nhl_inference(idₕ, idₐ, sₕ, sₐ, hw, priors)
        #priors_μ = get_posterior_μ(priors)
        #chain = sample(m, HMCDA(200, 0.65, 0.3), 500) #, init_theta = priors_μ)
        chain = sample(m, NUTS(200, 0.65), 500) #, init_theta = priors_μ)
    end

    priors = posteriors = get_posteriors(chain, n_teams)

    inferred = []
    push!(inferred, day)
    push!(inferred, InverseGamma(posteriors[:Δσₕ][1], posteriors[:Δσₕ][2]))         # Δ\sigmaₕ
    push!(inferred, InverseGamma(posteriors[:Δσᵢ][1], posteriors[:Δσᵢ][2]))         # Δ\sigmaᵢ
    push!(inferred, InverseGamma(posteriors[:Δσₜₑₐₘ][1], posteriors[:Δσₜₑₐₘ][2]))   # Δ\sigmaₜₑₐₘ
    push!(inferred, Normal(posteriors[:h][1], posteriors[:h][2]))                   # h
    push!(inferred, Normal(posteriors[:i][1], posteriors[:i][2]))                   # i
    for j = 1:n_teams
        push!(inferred, Normal(posteriors[:o][1][j], posteriors[:o][2][j]))         # oⱼ
        push!(inferred, Normal(posteriors[:d][1][j], posteriors[:d][2][j]))         # dⱼ
    end
    push!(inferred_variables, inferred)
end
# Out:
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[24]:18
# └ @ Core ./In[24]:18
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[24]:19
# └ @ Core ./In[24]:19
# 1
# ┌ Info: Found initial step size
# │   ϵ = 0.0125
# └ @ Turing.Inference /home/everett/.julia/packages/Turing/GMBTf/src/inference/hmc.jl:629
# Sampling: 100%|█████████████████████████████████████████| Time: 0:00:01
# InterruptException:
#
# Stacktrace:
#  [1] macro expansion at /home/everett/.julia/packages/FunctionWrappers/OAZAk/src/FunctionWrappers.jl:109 [inlined]
#  [2] do_ccall at /home/everett/.julia/packages/FunctionWrappers/OAZAk/src/FunctionWrappers.jl:100 [inlined]
#  [3] FunctionWrapper at /home/everett/.julia/packages/FunctionWrappers/OAZAk/src/FunctionWrappers.jl:116 [inlined]
#  [4] reverse_pass!(::ReverseDiff.CompiledTape{ReverseDiff.GradientTape{Turing.Core.var"#f#36"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector ...
#  [5] seeded_reverse_pass!(::DiffResults.MutableDiffResult{1,Float64,Tuple{Array{Float64,1}}}, ::ReverseDiff.TrackedReal{Float64,Float64,ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}}, ::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}, ::ReverseDiff.CompiledTape{ReverseDiff.GradientTape{Turing.Core.var"#f#36"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{F ...
#  [6] seeded_reverse_pass! at /home/everett/.julia/packages/ReverseDiff/uy0uk/src/api/tape.jl:47 [inlined]
#  [7] gradient! at /home/everett/.julia/packages/ReverseDiff/uy0uk/src/api/gradients.jl:80 [inlined]
#  [8] gradient_logp at /home/everett/.julia/packages/Turing/GMBTf/src/core/compat/reversediff.jl:70 [inlined]
#  [9] gradient_logp at /home/everett/.julia/packages/Turing/GMBTf/src/core/ad.jl:78 [inlined]
#  [10] ∂logπ∂θ at /home/everett/.julia/packages/Turing/GMBTf/src/inference/hmc.jl:474 [inlined]
#  [11] ∂H∂θ(::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64,Array{Float64,1}},Turing.Inference.var"#logπ#55"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{ ...
#  [12] macro expansion at /home/everett/.julia/packages/UnPack/1IjJI/src/UnPack.jl:100 [inlined]
#  [13] step(::AdvancedHMC.Leapfrog{Float64}, ::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64,Array{Float64,1}},Turing.Inference.var"#logπ#55"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{ ...
#  [14] step at /home/everett/.julia/packages/AdvancedHMC/P9wqk/src/integrator.jl:56 [inlined]
#  [15] build_tree(::Random._GLOBAL_RNG, ::AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64}, ::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64,Array{Float64,1}},Turing.Inference.var"#logπ#55"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},A ...
#  [16] build_tree(::Random._GLOBAL_RNG, ::AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64}, ::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64,Array{Float64,1}},Turing.Inference.var"#logπ#55"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},A ...
#  [17] transition(::Random._GLOBAL_RNG, ::AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64}, ::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64,Array{Float64,1}},Turing.Inference.var"#logπ#55"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},A ...
#  [18] step(::Random._GLOBAL_RNG, ::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64,Array{Float64,1}},Turing.Inference.var"#logπ#55"{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{Dynami ...
#  [19] step!(::Random._GLOBAL_RNG, ::DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}}, ::DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64},AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordVar{Float64,Array{Float64,1}},AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}},AdvancedHMC.PhasePoint{Array{Float64,1},AdvancedHMC.DualValue{Float64,Array{Float64,1}}}}}, ::Int64, ::Turing.Inference.HamiltonianTransition{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Float64,1},Array{String,1}},Tuple{Array{Array{Float64,1},1},Array{String,1}},Tuple{Array{Array{Float64,1},1},Array{String,1}},Tuple{Array{Array{Float64,1},1},Array{String,1}},Tuple{Array{Array{Float64,1},1},Array{String,1}}}},NamedTuple{(:n_steps, :is_accept, :acceptance_rate, :log_density, :hamiltonian_energy, :hamiltonian_energy_error, :max_hamiltonian_energy_error, :tree_depth, :numerical_error, :step_size, :nom_step_size),Tuple{Int64,Bool,Float64,Float64,Float64,Float64,Float64,Int64,Bool,Float64,Float64}},Float64}; kw ...
#  [20] macro expansion at /home/everett/.julia/packages/AbstractMCMC/iOkTf/src/sample.jl:93 [inlined]
#  [21] macro expansion at /home/everett/.julia/packages/ProgressLogging/BBN0b/src/ProgressLogging.jl:328 [inlined]
#  [22] (::AbstractMCMC.var"#18#21"{Bool,String,AbstractMCMC.var"#20#23",Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},Random._GLOBAL_RNG,DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64},AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordVar{Float64,Array{Float64,1}},AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}},AdvancedHMC.PhasePoint{Array{Float64,1},AdvancedHMC.DualValue{Float64,Array{Float64,1}}}}},Int64})() at /home/everett/.julia/packages/AbstractMCMC/iOkTf/src/logging.jl:11
#  [23] with_logstate(::AbstractMCMC.var"#18#21"{Bool,String,AbstractMCMC.var"#20#23",Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},Random._GLOBAL_RNG,DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}},DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64},AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordVar{Float64,Array{Float64,1}},AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}},AdvancedHMC.PhasePoint{Array{Float64,1},AdvancedHMC.DualValue{Float64,Array{Float64,1}}}}},Int64}, ::Base.CoreLogging.LogState) at ./logging.jl:398
#  [24] with_logger(::Function, ::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{ConsoleProgressMonitor.ProgressLogger,AbstractMCMC.var"#1#3"{Module}},LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger,AbstractMCMC.var"#2#4"{Module}}}}) at ./logging.jl:505
#  [25] with_progresslogger(::Function, ::Module, ::Base.CoreLogging.SimpleLogger) at /home/everett/.julia/packages/AbstractMCMC/iOkTf/src/logging.jl:34
#  [26] macro expansion at /home/everett/.julia/packages/AbstractMCMC/iOkTf/src/logging.jl:10 [inlined]
#  [27] mcmcsample(::Random._GLOBAL_RNG, ::DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}}, ::DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64},AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordVar{Float64,Array{Float64,1}},AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}},AdvancedHMC.PhasePoint{Array{Float64,1},AdvancedHMC.DualValue{Float64,Array{Float64,1}}}}}, ::Int64; progress::Bool, progressname::String, callback::AbstractMCMC.var"#20#23", chain_type::Type{T} where T, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/everett/.julia/packages/AbstractMCMC/iOkTf/src/sample.jl:76
#  [28] sample(::Random._GLOBAL_RNG, ::DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}}, ::DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64},AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordVar{Float64,Array{Float64,1}},AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}},AdvancedHMC.PhasePoint{Array{Float64,1},AdvancedHMC.DualValue{Float64,Array{Float64,1}}}}}, ::Int64; chain_type::Type{T} where T, resume_from::Nothing, progress::Bool, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/everett/.julia/packages/Turing/GMBTf/src/inference/Inference.jl:177
#  [29] sample(::Random._GLOBAL_RNG, ::DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}}, ::DynamicPPL.Sampler{NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric},Turing.Inference.HMCState{DynamicPPL.VarInfo{NamedTuple{(:Δσₕ, :Δσᵢ, :Δσₜₑₐₘ, :Δₕ, :Δᵢ, :h, :i, :o, :d, :Δo, :Δd),Tuple{DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₕ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσᵢ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},Int64},Array{InverseGamma{Float64},1},Array{DynamicPPL.VarName{:Δσₜₑₐₘ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δₕ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δₕ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δᵢ,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:Δᵢ,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:h,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:h,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:i,Tuple{}},Int64},Array{Normal{Float64},1},Array{DynamicPPL.VarName{:i,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:o,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:o,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:d,Tuple{}},Int64},Array{Product{Continuous,Normal{Float64},Array{Normal{Float64},1}},1},Array{DynamicPPL.VarName{:d,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δo,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δo,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}},DynamicPPL.Metadata{Dict{DynamicPPL.VarName{:Δd,Tuple{}},Int64},Array{DistributionsAD.TuringScalMvNormal{Array{Float64,1},Float64},1},Array{DynamicPPL.VarName{:Δd,Tuple{}},1},Array{Float64,1},Array{Set{DynamicPPL.Selector},1}}}},Float64},AdvancedHMC.NUTS{AdvancedHMC.MultinomialTS,AdvancedHMC.GeneralisedNoUTurn,AdvancedHMC.Leapfrog{Float64},Float64},AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordVar{Float64,Array{Float64,1}},AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}},AdvancedHMC.PhasePoint{Array{Float64,1},AdvancedHMC.DualValue{Float64,Array{Float64,1}}}}}, ::Int64) at /home/everett/.julia/packages/Turing/GMBTf/src/inference/Inference.jl:176
#  [30] sample(::Random._GLOBAL_RNG, ::DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}}, ::NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric}, ::Int64; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/everett/.julia/packages/Turing/GMBTf/src/inference/Inference.jl:163
#  [31] sample at /home/everett/.julia/packages/Turing/GMBTf/src/inference/Inference.jl:163 [inlined]
#  [32] #sample#1 at /home/everett/.julia/packages/Turing/GMBTf/src/inference/Inference.jl:153 [inlined]
#  [33] sample(::DynamicPPL.Model{var"###evaluator#618",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),Tuple{Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Array{Int64,1},Dict{Symbol,Tuple{Any,Any}}},(),DynamicPPL.ModelGen{var"###generator#619",(:idₕ, :idₐ, :sₕ, :sₐ, :hw, :p),(),Tuple{}}}, ::NUTS{Turing.Core.ReverseDiffAD{true},(),AdvancedHMC.DiagEuclideanMetric}, ::Int64) at /home/everett/.julia/packages/Turing/GMBTf/src/inference/Inference.jl:153
#  [34] top-level scope at In[24]:49

# %%
function nhl_inference_plot(lvars, ivars, vname)
    ldays = lvars[:,:day]
    ly = lvars[:,vname]
    idays = ivars[:,:day]
    iy = ivars[:,vname]
    iyμ = [y.μ for y in iy]
    iyσ = [y.σ for y in iy]
    plot(ldays, ly)
    plot!(idays, iyμ, ribbon=iyσ)
end
# Out:
# nhl_inference_plot (generic function with 1 method)

# %%
nhl_inference_plot(latent_variables[1:1000, :], inferred_variables, :h)

# %%
nhl_inference_plot(latent_variables[1:1000, :], inferred_variables, :i)

# %%
nhl_inference_plot(latent_variables[1:1000, :], inferred_variables, :o4)

# %%
nhl_inference_plot(latent_variables[1:1000, :], inferred_variables, :o1)
